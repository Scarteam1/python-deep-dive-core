# %%
i = 6

while True:
    print(i)
    if i >= 6:
        break
        print('Nothing')
# Out:
# 6

# %%
min_length = 2

while True:
    name=('please put your name')
    if len(name) >= min_length and name.isprintable() and name.isalpha():
        break

# %%
Sunhik

# %%
2

# %%
1
