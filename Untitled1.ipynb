# %%
# my_module.py
public_var = "Everyone can see me"
_internal_var = "Please treat me as private"

# main.py
print(public_var)      # Works fine
print(_internal_var)  # NameError: name '_internal_var' is not defined

# %%
from my_module import *

print(public_var)      # This works fine!
print(_internal_var)   # This WILL give you a NameError now!

# %%
import math
print(math.sqrt(16))  # Must prefix with "math."

# %%
from math import *
print(sqrt(16))       # Used directly without "math."

# %%
a = 6

if a < 5:
    print ("a < 5")
else:
    print ("a >=5")

# %%
a = 9

if a < 5:
    print ('a is less than 10')
elif a >= 5 and a < 10:
    print ('a is greatr than 5 but less tha 10')

# %%
a = [1,2,3]
len(a)

# %%
import math

# %%
sqrt(4)

# %%
exp(2)

# %%
pi

# %%
def func_1():
    print('Calling function')

# %%
func_1()

# %%
def func_2(a: int, b: int):
    return a * b

# %%
import math

# %%
func_2(a,3)

# %%
print(a)

# %%
def func_3(a: letter , b: int):
    return a * b

# %%
func_3('a', 3)

# %%
import math

# %%
func_3('a',3)
