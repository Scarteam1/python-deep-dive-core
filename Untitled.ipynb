# %%
a=[1,2,3]
print (a)
# Out:
# [1, 2, 3]

# %%
a=[1, #this is comment 
   2]
print (a)
# Out:
# [1, 2]

# %%
a={ 'what am i doing': 'setting up Jupyter lab',
'Is it success': 'Yes'
}

print(a)
# Out:
# {'what am i doing': 'setting up Jupyter lab', 'Is it success': 'Yes'}

# %%
def my_func(name):
    print(f"Hello, {name}!")

my_func("Sunhik")
# Out:
# Hello, Sunhik!

# %%
def my_func(number):
    return number * 2
    
result = my_func(5)
print(result)
# Out:
# 10

# %%
def my_func(number):
    return number * 2

result = my_func(5)  # result is now 10
print(result)
# Out:
# 10

# %%
def my_func(status="Success"):
    if a='1'
    print(f"The state is: {status}")

my_func()
or
my_func(status="Failed")
# Out:
#   Cell In[32], line 2
#     if a='1'
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
def my_func(number):
    print(f"number={number}")

my_number=[10,20,30]
my_func(my_number)
# Out:
# number=[10, 20, 30]

# %%
my_func(10,
        20,
        30
       )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 my_func(10,
#       2         20,
#       3         30
#       4        )
#
# TypeError: my_func() takes 1 positional argument but 3 were given

# %%
def my_func(a,b,c):
    print(10,20,30)

# %%
my_func(10,20,30)
# Out:
# 10 20 30

# %%
a=10
b=20
c=30

# %%
if a > 5 \
and b > 10 \
and c > 20:
    print('Yes')
# Out:
# Yes

# %%
a = '''What a good day'''

# %%
a
# Out:
# 'What a good day'
