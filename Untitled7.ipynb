# %%
my_var = [10,20,30]

# %%
print(hex(id(my_var)))
# Out:
# 0x21b1ac7da40

# %%
other_var = my_var

# %%
print(hex(id(other_var)))
# Out:
# 0x7ff9e45ca4c8

# %%
import sys

# %%
print(sys.getrefcount(my_var))
# Out:
# 2

# %%
print(sys.getrefcount(other_var))
# Out:
# 4294967295

# %%
test_var = [1,2,3]

# %%
print(sys.getrefcount(test_var))
# Out:
# 2

# %%
second_var = test_var

# %%
print(sys.getrefcount(second_var))
# Out:
# 3

# %%
new_var = [1,2,3]

# %%
object_A
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 object_A
#
# NameError: name 'object_A' is not defined

# %%
import gc

# %%
print (gc.get_threshold())
# Out:
# (2000, 10, 10)

# %%
print (gc.get_count())
# Out:
# (635, 3, 0)

# %%
class Node:
    def __ini__(self,name):
        self.name = name
        self.pointer = None

# %%
A = Node("server A")
B = Node("server B")

A.pointer = B
B.pointer = A

del A
del B
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 A=Node("server A")
#       2 B=Node("server B")
#       4 A.pointer = B
#
# TypeError: Node() takes no arguments
