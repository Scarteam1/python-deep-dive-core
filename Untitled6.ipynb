# %%
a = [1,2,3]

# %%
b = a

# %%
print(id(a))
# Out:
# 2958172999424

# %%
print(id(b))
# Out:
# 2958172999424

# %%
list1 = [1,2,3]

# %%
list2 =[ 1,2,3]

# %%
print(list1 == list2)
# Out:
# True

# %%
print(list1 is list2)
# Out:
# False

# %%
x = 10

# %%
y = 10

# %%
print ( x is y)
# Out:
# True

# %%
print (x)
# Out:
# 10

# %%
print (hex(id(a)))
# Out:
# 0x2b0c0d9cf00

# %%
import sys

# %%
import sys

my_list = [1,2,3]

print(sys.getrefcount(my_list))
# Out:
# 2
