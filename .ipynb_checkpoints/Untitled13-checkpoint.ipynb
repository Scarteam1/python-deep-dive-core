# %%
print(type(100))
# Out:
# <class 'int'>

# %%
print(type("Python"))
# Out:
# <class 'str'>

# %%
import sys

# %%
sys.getsizeof(0)
# Out:
# 28

# %%
sys.getsizeof(100)
# Out:
# 28

# %%
sys.getsizeof(2**100)
# Out:
# 40

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\sunhi
