# %%
import sys

# %%
server_A = "String Interning"

# %%
server_B = "String Interning"

# %%
print ("Are they equal", server_A == server_B)
# Out:
# Are they equal True

# %%
print ("Are they equal:", server_A is server_B)
# Out:
# Are they equal: True

# %%
print (id(server_A) , id(server_B))
# Out:
# 2306145899888 2306143648112

# %%
server_A = sys.intern("String Interning")

# %%
server_B = sys.intern("String Interning")

# %%
print (id(server_A) , id(server_B))
# Out:
# 2306143991280 2306143991280

# %%
def my_time_function():
    hours_to_seconds = 60*60*24
    return hours_to_seconds

# %%
print (my_time_function)
# Out:
# <function my_time_function at 0x00000218F0F2A660>

# %%
print(my_time_function.__code__.co_consts)
# Out:
# (None, 86400)

# %%
import datetime
my_time = 60 * 60 * 24

# %%
print (my_time,"mins")
# Out:
# 86400 mins
