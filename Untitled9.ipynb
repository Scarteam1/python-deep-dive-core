# %%
my_list = ["apple", "banana"]

# %%
my_list.append("orange")

# %%
print (my_list)
# Out:
# ['apple', 'banana', 'orange']

# %%
list_a = ["Linux", "Python"]
list_b = list_a  # Shared Reference! Both tags look at the exact same box.

# 2. Mutate the container using the 'list_b' tag
list_b.append("MLOps")

# 3. Check what happened to 'list_a'
print("list_a looks like:", list_a)
print("list_b looks like:", list_b)
# Out:
# list_a looks like: ['Linux', 'Python', 'MLOps']
# list_b looks like: ['Linux', 'Python', 'MLOps']

# %%
list_a = ["Server A"]
list_b = ["Server A"]

print(id(list_a) == id(list_b))
# Out:
# False

# %%
str_a = "Server A"
str_b = "Server A"  # Change this to match str_a exactly!

print(id(str_a) == id(str_b))
# Out:
# False

# %%
del str_a

# %%
del str_b

# %%
str_a = "Server_A"
str_b = "Server_A"  # Change this to match str_a exactly!

print(id(str_a) == id(str_b))
# Out:
# True

# %%
list_1 = ["Linux"]
list_2 = ["Linux"]

# %%
print(list_1 == list_2)
# Out:
# True

# %%
print(list_1 is list_2)
# Out:
# False
