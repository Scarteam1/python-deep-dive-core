# %%
1/3
# Out:
# 0.3333333333333333

# %%
import math

# %% [markdown]
# from fraction

# %%
from fractions import Fraction

# %%
Fraction(1,3)
# Out:
# Fraction(1, 3)

# %%
import sys

# %%
print (sys.getsizeof(0))
# Out:
# 28

# %%
print (sys.getsizeof(2**30))
# Out:
# 32

# %%
print (sys.getsizeof(2**60))
# Out:
# 36

# %%
print(sys.int_info)
# Out:
# sys.int_info(bits_per_digit=30, sizeof_digit=4, default_max_str_digits=4300, str_digits_check_threshold=640)

# %%
print (sys.getsizeof(2**2))
# Out:
# 28

# %%
print (sys.getsizeof(2**3))
# Out:
# 28

# %%
print (sys.getsizeof(2**4))
# Out:
# 28

# %%
print (sys.getsizeof(2**10))
# Out:
# 28

# %%
print (sys.getsizeof(2**29))
# Out:
# 28

# %%
print (sys.getsizeof(4**2))
# Out:
# 28

# %%
print (sys.getsizeof(4**28))
# Out:
# 32

# %%
print (sys.getsizeof(4**10))
# Out:
# 28

# %%
print (sys.getsizeof(4**20))
# Out:
# 32

# %%
print (sys.getsizeof(4**19))
# Out:
# 32

# %%
print (sys.getsizeof(4**16))
# Out:
# 32

# %%
print (sys.getsizeof(4**15))
# Out:
# 32

# %%
print (sys.getsizeof(4**14))
# Out:
# 28
