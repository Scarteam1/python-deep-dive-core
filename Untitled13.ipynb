# %%
print(type(100))
# Out:
# <class 'int'>

# %%
print(type("Python"))
# Out:
# <class 'str'>

# %%
import sys

# %%
sys.getsizeof(0)
# Out:
# 28

# %%
sys.getsizeof(100)
# Out:
# 28

# %%
sys.getsizeof(2**100)
# Out:
# 40

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\sunhi

# %%
10 + 5
# Out:
# 15

# %%
(10).__add__(5)
# Out:
# 15

# %% [markdown]
# 10 / 5

# %%
10/5
# Out:
# 2.0

# %%
10%3
# Out:
# 1

# %%
100%5
# Out:
# 0

# %%
print(-10 % 3)
# Out:
# 2

# %%
print(10 % 3)
# Out:
# 1

# %%
10 % 3
# Out:
# 1

# %%
(10).__mod__(3)
# Out:
# 1

# %%
155/4
# Out:
# 38.75

# %%
155//4
# Out:
# 38

# %%
155%4
# Out:
# 3
