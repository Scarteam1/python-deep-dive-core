# %%
##Coercing to Integer

# %%
import math

x = 3.8

# %%
print(int(x))
# Out:
# 3

# %%
print(math.trunc(x))
# Out:
# 3

# %%
print(math.ceil(x))
# Out:
# 4

# %%
print(round(x))
print(math.floor(x))
# Out:
# 4
# 3

# %%
y = -3.6

print(int(y))
print(math.trunc(y))
print(math.ceil(y))
print(round(y))
print(math.floor(y))
# Out:
# -3
# -3
# -3
# -4
# -4

# %%
import math

# %%
a = 1
b = 2

# %%
print (a^b)
# Out:
# 3

# %%
type (b)
# Out:
# int

# %%
c = round(1.2367, 4)
d = round(2.4234, 5)

e = round((c+d), 5)

e, type(e)
# Out:
# (3.6601, float)
