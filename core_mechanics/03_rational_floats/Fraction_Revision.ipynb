# %%
from fractions import Fraction

f1 = Fraction(1,3)
print(f1)
# Out:
# 1/3

# %%
f2 = Fraction(0.234)

# %%
print(f2)
# Out:
# 8430738502437569/36028797018963968

# %%
import math

# %%
f1 = 0.1 + 0.2
f2 = 0.3

print (f1 == f2)

print (math.isclose(f1,f2))
# Out:
# False
# True

# %%
print(math.isclose(f1, f2, rel_tol=1e-12))
# Out:
# True

# %%
x = 0.1

format(x, '.9f')
# Out:
# '0.100000000'
