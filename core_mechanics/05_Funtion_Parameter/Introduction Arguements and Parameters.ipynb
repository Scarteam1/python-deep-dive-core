# %%
def make_combo_meal (Burger, Fries, Drink):
    print("Burger slot hold: ", Burger)
    print("Fries slot hold: ", Fries)
    print("Drinks slot hold: ", Drink)

make_combo_meal("Large Fries", "McChicken", "Coca-Cola")
# Out:
# Burger slot hold:  Large Fries
# Fries slot hold:  McChicken
# Drinks slot hold:  Coca-Cola

# %%
### We can do like the below

# %%
Burger = input("")
Fries = input ("")
Drinks = input("")

if Burger in ("McChicken", "McCheese"):
    print(Burger)
else:
    print("Insert correct item")

if Fries in ("Large Fries", "Medium Fries"):
    print(Fries)
else:
    print("Insert correct item")

if Drinks in ("Coca-Cola", "Sprite"):
    print(Drinks)
else:
    print("Insert correct item")

print(f"Your combo meal is: {Burger}, {Fries}, {Drinks}")
# Out:
#  McChicken
#  Large Fries
#  Coca-Cola
# McChicken
# Large Fries
# Coca-Cola
# Your combo meal is: McChicken, Large Fries, Coca-Cola

# %%
# 1. The reusable machine blueprint (from our earlier experiment)
def make_combo_meal(rice, vegies, chicken):
    print("\n--- Processing Order inside Machine ---")
    print("Rice Slot holds:", rice)
    print("Vegies Slot holds:", vegies)
    print("Chicken Slot holds:", chicken)

# 2. Feeding your validated inputs into the function as POSITIONAL ARGUMENTS
# Because 'Burger' is typed first, its value automatically drops into the first parameter slot!
make_combo_meal(Rice, Vegies, Chicken)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 10
#       6     print("Chicken Slot holds:", chicken)
#       8 # 2. Feeding your validated inputs into the function as POSITIONAL ARGUMENTS
#       9 # Because 'Burger' is typed first, its value automatically drops into the first parameter slot!
# ---> 10 make_combo_meal(Rice, Vegies, Chicken)
#
# NameError: name 'Rice' is not defined
