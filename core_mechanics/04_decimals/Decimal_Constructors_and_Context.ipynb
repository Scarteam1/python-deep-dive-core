# %%
import decimal
from decimal import Decimal

# %%
print(decimal.getcontext().prec)

with decimal.localcontext() as local:
    local.prec = 4

input_a = input()
input_b = input()
input_c = input()

a = Decimal(input_a)
b = Decimal(input_b)
c = Decimal(input_c)

local_output = (a + b + c)
print(local_output)
# Out:
# 28
#  0.4
#  0.3
#  0.8
# 1.5
