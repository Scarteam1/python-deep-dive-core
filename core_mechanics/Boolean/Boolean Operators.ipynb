# %%
import math

x = int(input(""))
y = int
if x <= 5:
    print("Number is less that or equal to 5",x)

else:
    print("Number is greater than 5")
# Out:
#  8
# Number is greater than 5

# %%
x = int(input(""))

output = (x<5) or (x>5) or (x==5)
print(output)
# Out:
#  7
# True

# %%
x = int(input(""))

output = (x<5 and "Result is less than 5") or ( x==5 and "Result is equal to 5") or (x>5 and "Result is more than 5")
print(output)
# Out:
#  5
# Result is equal to 5
