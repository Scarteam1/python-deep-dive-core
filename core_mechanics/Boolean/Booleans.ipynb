# %%
print(type(True), id(True), int(True))
print(type(False), id(False), int(False))
# Out:
# <class 'bool'> 140725332326880 1
# <class 'bool'> 140725332326912 0

# %%
print(hex(True))
# Out:
# 0x1

# %%
print(True * 50)
# Out:
# 50

# %%
my_text= input("")

if not my_text:
    print("Textbox is empty")
# Out:
# Textbox is empty

# %%
my_text= input("")

if not my_text:
    print("Textbox is empty")
# Out:
#  Sunhik

# %%
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False
