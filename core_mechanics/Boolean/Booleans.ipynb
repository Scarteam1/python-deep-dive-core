# %%
print(int(True))
# Out:
# 1

# %%
print(hex(True))
# Out:
# 0x1

# %%
print(True * 50)
# Out:
# 50

# %%
my_text= input("")

if not my_text:
    print("Textbox is empty")
# Out:
# Textbox is empty

# %%
my_text= input("")

if not my_text:
    print("Textbox is empty")
# Out:
#  Sunhik
